# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("spectre_bol_tibétain.txt", sep='\t')

# %%
peaks=[402,1155,2168,3372,4380,5354]
amps = [-30.6,-22,-28.2,-44.9,-63.7,-68.4]
plt.plot(peaks, 'o-')
plt.show()

# %%
plt.plot(df.set_index("Frequency (Hz)"))
for peak in peaks:
    plt.axvline(x=peak, lw=1, ls='--')
for peak, amp in zip(peaks, amps):
    plt.plot(peak, amp, 'o')
plt.show()
